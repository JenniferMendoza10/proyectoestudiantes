# %% [markdown]
# 1.	En un salón de clases de 10 estudiantes se ha rendido cinco exámenes. Elabore un programa que almacene las notas que obtuvieron los alumnos en los exámenes y muestre una tabla con los promedios de cada alumno y el resumen del salón.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def aaa(vector):
  sv=sum(vector)
  pr=sv/len(vector)
  return pr

def sumaCol(matriz):
  VS=[]
  for c in range(0, len(matriz[0])):
    s=0
    for f in range(0, len(matriz)):
      s=s+matriz[f][c]
      ss=s/tamF
    VS.append(ss)
  return VS

def crearM(N,M):
  A=[]
  for f in range(1, N+1):
    VF=[]
    for c in range(1, 6):
      t=float(input("ingrese notas del alumno: "))
      num=t
      VF.append(num)
      z=aaa(VF)
    print("El promedio del estudiante es: ", z)
    VF.append(z)
    A.append(VF)
    ss=sumaCol(A)
  print("El resumen del salón es: ", ss)
  A.append(ss)
  return A

def imprimirM(matriz):
  for f in range(0, len(matriz)):
    for c in range(0, len(matriz[f])):
      print(matriz[f][c], end="\t")
    print()


tamF=2
tamC=5
B=crearM(tamF, tamC)
imprimirM(B)
# Out:
# ingrese notas del alumno: 15
# ingrese notas del alumno: 15
# ingrese notas del alumno: 17
# ingrese notas del alumno: 15
# ingrese notas del alumno: 16
# El promedio del estudiante es:  15.6
# ingrese notas del alumno: 17
# ingrese notas del alumno: 18
# ingrese notas del alumno: 19
# ingrese notas del alumno: 20
# ingrese notas del alumno: 13
# El promedio del estudiante es:  17.4
# El resumen del salón es:  [16.0, 16.5, 18.0, 17.5, 14.5, 16.5]
# 15.0	15.0	17.0	15.0	16.0	15.6
# 17.0	18.0	19.0	20.0	13.0	17.4
# 16.0	16.5	18.0	17.5	14.5	16.5
